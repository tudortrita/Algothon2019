# %% [markdown]
# IQBanker Global Supply Chain Relationships

# %%
import pandas as pd
import quandl

# %%
quandl.ApiConfig.api_key = ""

# %%
df = quandl.get_table('GSCR/GSREF', publish_date='2018-05-18', exchange='ADX')

# %%
df
# Out:
#      publish_date exchange      ticker                   lei          isin  \
# None
# 0      2018-05-18      ADX  ADAVIATION                  None  AEA001001014
# 1      2018-05-18      ADX      AGTHIA                  None  AEA001901015
# 2      2018-05-18      ADX        DANA                  None  AED000701014
# 3      2018-05-18      ADX    ETISALAT  529900XDPQPWEQ9BGB80  AEE000401019
# 4      2018-05-18      ADX     JULPHAR                  None  AEG000201018
# 5      2018-05-18      ADX        NBAD  2138002Y3WMK6RZS8H90  AEN000101016
# 6      2018-05-18      ADX     RAKBANK  254900CDNPJRAT391Y16  AEN000601015
# 7      2018-05-18      ADX        TAQA  213800UNJSVQFNUYYW03  AEA002401015
# 8      2018-05-18      ADX         UAB  254900MX6MPZTKMTS474  AEU000601010
# 9      2018-05-18      ADX        GMPC                  None  AEG000401014
# 10     2018-05-18      ADX        ADNH                  None  AEA000301019
#
# ...
